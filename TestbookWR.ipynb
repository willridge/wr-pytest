# %% [markdown]
# # MC316 Practice Test – PYTHON

# %% [markdown]
# Please read the questions carefully. You will have 30 minutes to finish the test.

# %% [markdown]
# #### Please import pandas library for use in scripting in the cell below.

# %%
import pandas as pd

# %% [markdown]
# #### Please import the datasets and name them.
# For this test, you will use employee compensation data provided by Kansas Department of Administration. Download the original data here: <http://kanview.ks.gov/DataDownload.aspx>.
# For your convenience, the datasets were downloaded and uploaded to the instructor's database. You can retrieve the url for the first dataset from  <https://datajournalism.tech/wp-content/uploads/2019/05/EmployeeData_2017.csv> and the second dataset from
# <https://datajournalism.tech/wp-content/uploads/2019/05/EmployeeData_2018.csv>

# %%
first = pd.read_csv("https://datajournalism.tech/wp-content/uploads/2019/05/EmployeeData_2017.csv")

# %%
second = pd.read_csv("https://datajournalism.tech/wp-content/uploads/2019/05/EmployeeData_2018.csv")

# %% [markdown]
# #### Please describe the two datasets.

# %%
first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39422 entries, 0 to 39421
# Data columns (total 7 columns):
# Agency_Number      39422 non-null int64
# Agency_Name        39422 non-null object
# Employee_Name      39422 non-null object
# Job_Title          39422 non-null object
# Total_Gross_Pay    39422 non-null float64
# Overtime_Pay       8615 non-null float64
# Unnamed: 6         0 non-null float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 2.1+ MB

# %%
second.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39299 entries, 0 to 39298
# Data columns (total 8 columns):
# Fiscal_Year        39299 non-null int64
# Agency_Number      39299 non-null int64
# Agency_Name        39299 non-null object
# Employee_Name      39299 non-null object
# Job_Title          39299 non-null object
# Total_Gross_Pay    39299 non-null float64
# Overtime_Pay       39299 non-null float64
# Unnamed: 7         0 non-null float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 2.4+ MB

# %% [markdown]
# #### Question 1: In the year of 2017,  which agency has the most employees?
# After writing the code, make sure you give the answer in the cell right below the code.

# %%
first.Agency_Name.value_counts()
# Out:
# Kansas State University                5367
# University of Kansas                   5207
# University of Kansas Medical Center    3419
# Wichita State University               2248
# Department of Transportation           2180
# Dept for Children and Families         2130
# Judicial Branch                        1833
# Fort Hays State University             1411
# Department of Revenue                  1033
# Dept of Health & Environment           1010
# Pittsburg State University              957
# KS Wildlife  Parks & Tourism            815
# Highway Patrol                          787
# Emporia State University                761
# Larned State Hospital                   669
# Lansing Correctional Facility           540
# Department of Administration            448
# Hutchinson Correctional Fclty           446
# Parsons St Hosp & Trng Center           433
# Osawatomie State Hospital               390
# Kansas Neurological Institute           389
# Legislature                             383
# Department of Corrections               377
# Department of Labor                     371
# El Dorado Correctional Fclty            358
# Kansas Dept of Agriculture              355
# Veterans Commission                     305
# Kansas Bureau of Investigation          285
# Dept of Commerce                        250
# Ks Dept for Aging & Disab Svs           246
#                                        ...
# Kansas State Fair Board                  31
# Kansas Water Office                      31
# Board of Nursing                         29
# State Library                            26
# Emergency Medical Services               23
# Board of Cosmetology                     23
# Legislative Coordinating CncL            21
# Behavioral Sciences Reg Board            21
# Hlth Care Stabilization Fund B           20
# Board of Pharmacy                        20
# Kansas Human Rights Commission           20
# Kansas Sentencing Commission             18
# KS Gvmtl Ethics Commission               18
# Technical Professions St Bd              18
# Department of Credit Unions              18
# Office of Adminstratv Hearings           17
# Court of Tax Appeals                     16
# Real Estate Commission                   15
# Citizens Utility Ratepayer Bd            11
# Board of Veterinary Examiners            11
# Dental Board                             11
# KS Comm Peace Ofcrs Std & Trng            9
# 10323          0.00         NaN
# 10324          0.00         NaN
# 10325          0.00         NaN
# 10326          0.00         NaN
# 10327          0.00         NaN
# 10328          0.00         NaN
# 10329          0.00         NaN
# 10330          0.00         NaN
# 10331          0.00         NaN
# 10332          0.00         NaN
# 10333          0.00         NaN
# 10334          0.00         NaN
# 10335          0.00         NaN
# 10336          0.00         NaN
# 10337          0.00         NaN
# 10338          0.00         NaN
# 10339          0.00         NaN
# 10340          0.00         NaN
# 10341          0.00         NaN
# 10342          0.00         NaN
# 10343          0.00         NaN
# 10344          0.00         NaN
# 10345          0.00         NaN
# 10346          0.00         NaN
# 10347          0.00         NaN
# 10348       3483.04         NaN
# 10349          0.00         NaN
# 10350          0.00         NaN
# 10351          0.00         NaN
# 10352          0.00         NaN
# ...             ...         ...
# 15757          0.00         NaN
# 15758          0.00         NaN
# 15759          0.00         NaN
# 15760          0.00         NaN
# 15761          0.00         NaN
# 15762          0.00         NaN
# 15763          0.00         NaN
# 15764          0.00         NaN
# 15765          0.00         NaN
# 15766          0.00         NaN
# 15767          0.00         NaN
# 15768          0.00         NaN
# 15769          0.00         NaN
# 15770          0.00         NaN
# 15771          0.00         NaN
# 15772          0.00         NaN
# 15773          0.00         NaN
# 15774          0.00         NaN
# 15775          0.00         NaN
# 15776          0.00         NaN
# 15777          0.00         NaN
# 15778          0.00         NaN
# 15779          0.00         NaN
# 15780          0.00         NaN
# 15781          0.00         NaN
# 15782          0.00         NaN
# 15783          0.00         NaN
# 15784          0.00         NaN
# 15785          0.00         NaN
# 15786          0.00         NaN
#
# [5464 rows x 8 columns]

# %% [markdown]
# Answer: See table yourself

# %% [markdown]
# #### Question 4: At Kansas University University, who got paid the most in the year of 2018? Is it considered an increase or decrease of compensation for that employee, compared to the year of 2017? How big is the difference?

# %%
merged = pd.merge(KSU, first, on="Employee_Name")

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4600 entries, 0 to 4599
# Data columns (total 14 columns):
# Fiscal_Year          4600 non-null int64
# Agency_Number_x      4600 non-null int64
# Agency_Name_x        4600 non-null object
# Employee_Name        4600 non-null object
# Job_Title_x          4600 non-null object
# Total_Gross_Pay_x    4600 non-null float64
# Overtime_Pay_x       4600 non-null float64
# Unnamed: 7           0 non-null float64
# Agency_Number_y      4600 non-null int64
# Agency_Name_y        4600 non-null object
# Job_Title_y          4600 non-null object
# Total_Gross_Pay_y    4600 non-null float64
# Overtime_Pay_y       482 non-null float64
# Unnamed: 6           0 non-null float64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 539.1+ KB

# %%
merged.groupby(["Employee_Name", "Job_Title_x", "Total_Gross_Pay_y" ]).Total_Gross_Pay_x.sum().reset_index().sort_values("Total_Gross_Pay_x", ascending=False).head()
# Out:
#                Employee_Name            Job_Title_x  Total_Gross_Pay_y  \
# 2863        Myers  Richard B              President          454615.35
# 3993          Taylor  Gene F  Director of Athletics           60576.95
# 1023  Dorhout  Peter Kenneth         Vice President          332307.63
# 912   Dawson  Darren Merritt         Dean-Professor          328361.58
# 1529  Gwinner  Kevin Patrick         Dean-Professor          345361.58
#
#       Total_Gross_Pay_x
# 2863          531250.02
# 3993          450000.20
# 1023          327815.27
# 912           323922.66
# 1529          323922.66

# %%
454615.35-531250.02
# Out:
# -76634.67000000004

# %% [markdown]
# Answer: President Myeres was the Highest paid for both years. He got a 76634.67000000004 raise

# %% [markdown]
# ### END OF THE TEST
